# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv('/content/drive/MyDrive/Assignment_Statistics/data.csv')

# %%
df.head()
# Out:
#    Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0           1                            130                           120
# 1           2                            142                           135
# 2           3                            120                           118
# 3           4                            135                           127
# 4           5                            148                           140

# %%
df['change_in_BP'] = df[' Blood Pressure Before (mmHg)'] - df[' Blood Pressure After (mmHg)']

# %%
df['change_in_BP']
# Out:
# 0     10
# 1      7
# 2      2
# 3      8
# 4      8
#       ..
# 95     7
# 96     6
# 97     4
# 98     4
# 99     5
# Name: change_in_BP, Length: 100, dtype: int64

# %%
# Method 1
sns.kdeplot(df['change_in_BP'])
# Out:
# <Axes: xlabel='change_in_BP', ylabel='Density'>

# %%
# As we can clearly see it is almost a normal distribution

# %%
# Method 2
df['change_in_BP'].skew()
# Out:
# 0.19543801617688214

# %%
# As we can clearly see skewness is very near to zero so it suggest it is almost normal distribution
